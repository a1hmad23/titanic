# %% [markdown]
# # Load Data

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
TRAIN_CSV = 'train.csv'
TEST_CSV = 'test.csv'

def load_data(csv_name):
    csv_path = os.path.join('datasets', csv_name)
    return pd.read_csv(csv_path)

# %%
train_set = load_data(TRAIN_CSV)
test_set = load_data(TEST_CSV)

# %%
train_set
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# test_set

# %%
X_train = train_set.drop(columns='Survived')
y_train = train_set['Survived']

# %% [markdown]
# # Exploratory Data Analysis

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
X_train.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
X_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
X_train.describe(include='object')
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
X_train.hist(figsize=(12, 8))
plt.show()

# %%
X_train['Fare'].hist(bins=50)
# Out:
# <Axes: >

# %%
for col in X_train.select_dtypes(include='object').columns:
    X_train[col].value_counts().plot(kind='bar')
    plt.xlabel(col)
    plt.show()

# %%
X_train['Cabin'].str[0].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
deck = X_train['Cabin'].str[0].value_counts()
deck.plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin'>

# %%
X_train = train_set.drop(columns='Survived')

# %%
X_train.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
def make_col_off_first_letter(df, old_col, new_col):
    df[new_col] = df[old_col].str[0]
    return df

# %%
make_col_off_first_letter(X_train, 'Cabin', 'Deck')

# %%
def make_col_off_rep_values(df, old_col, null_values=-10):
    df['Shared_' + old_col] = df[old_col].map(df[old_col].value_counts() > 1)
    return df

# %%
make_col_off_rep_values(X_train, 'Cabin')

# %%
make_col_off_rep_values(X_train, 'Ticket')

# %%
def col_per_counts_col(df, col, counts_col):
    counts = df[counts_col].map(df[counts_col].value_counts())
    df[col + ' per ' + counts_col + ' count'] = df[col] / no_of_Tickets
    return df

# %%
col_per_counts_col(X_train, 'Fare', 'Ticket')

# %%
X_train.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked Deck  \
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S  NaN
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C    C
#
#   Shared_Cabin  Shared_Ticket  Fare per Ticket count
# 0          NaN          False                 7.2500
# 1        False          False                71.2833

# %%
X_train['Fare per Ticket count'].hist(bins=50)
# Out:
# <Axes: >

# %%
X_train['Fare per Ticket count'][X_train['Fare per Ticket count'] < 20].hist(bins=50)
# Out:
# <Axes: >

# %%
X_train['Fare per Ticket count'][(X_train['Fare per Ticket count'] > 20) & (X_train['Fare per Ticket count'] < 100)].hist(bins=50)
# Out:
# <Axes: >

# %%
X_train['Fare per Ticket count'][X_train['Fare per Ticket count'] > 100].hist(bins=50)
# Out:
# <Axes: >

# %%
X_train['Fare per Ticket count'].describe()
# Out:
# count    891.000000
# mean      17.788989
# std       21.218157
# min        0.000000
# 25%        7.762500
# 50%        8.850000
# 75%       24.288200
# max      221.779200
# Name: Fare_Per_Person, dtype: float64

# %%
fare_bins = [0, 6, 13, 20, 40, 80, 222]
fare_labels = ['very low', 'low', 'medium', 'high', 'very high', 'extremely high']

# %%
(X_train['Ticket'].str.split(' ').apply(lambda x: len(x)) > 1).sum() # letters infornt of number
# Out:
# np.int64(226)

# %%
y_train.loc[(X_train['Ticket'].str.split(' ').apply(lambda x: len(x)) > 1)].sum() / 226
# Out:
# np.float64(0.38495575221238937)

# %%
y_train.sum()/len(y_train) #same as for tickets with letters infront
# Out:
# np.float64(0.3838383838383838)

# %%
X_train[['Parch', 'SibSp']].hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'SibSp'}>]], dtype=object)

# %%
def zero_or_greater(df, col):
    df['binary_' + col] = df[col].map(lambda x: 0 if x == 0 else 1)
    return df

# %%
zero_or_greater(X_train, 'SibSp')
zero_or_greater(X_train, 'Parch')

# %%
X_train.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked Deck  \
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S  NaN
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C    C
#
#   Shared_Cabin  Shared_Ticket  Fare per Ticket count  binary_SibSp  \
# 0          NaN          False                 7.2500             1
# 1        False          False                71.2833             1
#
#    binary_Parch
# 0             0
# 1             0

# %%
X_train['Age'].hist(bins=100)
# Out:
# <Axes: >

# %%
age_bins = [0, 12, 17, 24, 44, 64, float('inf')]
age_labels = ["Child", "Teenager", "Young Adult", "Adult", "Middle-Aged", "Senior"]

# %%
def make_col_off_second_word(df, old_col, new_col):
    df[new_col] = df[old_col].str.split(' ').apply(lambda x: x[1])
    return df

# %%
make_col_off_second_word(X_train, 'Name', 'Title')

# %%
X_train['Title'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Title'>

# %%
def group_title(df, col):
    df[col] = df[col].replace({
    'Capt.':'Military', 
    'Major.':'Military',
    'Col.':'Military',
    'Jonkheer.':'Noble',
    'the Countess':'Noble',
    'Don.':'Noble',
    'Lady':'Noble',
    'Sir':'Noble',
    'Mlle.':'Noble',
    'Ms.':'Noble',
    'Mme.':'Noble'
})
    return df

# %% [markdown]
# # functions

# %%
def make_col_off_second_word(df, old_col, new_col):
    df[new_col] = df[old_col].str.split(' ').apply(lambda x: x[1])
    return df

# %%
def group_title(df, col):
    df[col] = df[col].replace({
    'Capt.':'Military', 
    'Major.':'Military',
    'Col.':'Military',
    'Jonkheer.':'Noble',
    'the Countess':'Noble',
    'Don.':'Noble',
    'Lady':'Noble',
    'Sir':'Noble',
    'Mlle.':'Noble',
    'Ms.':'Noble',
    'Mme.':'Noble'
})
    return df

# %%
def zero_or_greater(df, col):
    df['binary_' + col] = df[col].map(lambda x: 0 if x == 0 else 1)
    return df

# %%
def col_per_counts_col(df, col, counts_col):
    counts = df[counts_col].map(df[counts_col].value_counts())
    df[col + ' per ' + counts_col + ' count'] = df[col] / no_of_Tickets
    return df

# %%
def make_col_off_rep_values(df, old_col):
    df['Shared_' + old_col] = df[old_col].map(df[old_col].value_counts() > 1)
    return df

# %%
def make_col_off_first_letter(df, old_col, new_col):
    df[new_col] = df[old_col].str[0]
    return df

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline

title_pipeline = Pipeline([
    ('make_title', FunctionTransformer(make_col_off_second_word, kw_args={'old_col':'Name', 'new_col':'Title'}, validate=False, feature_names_out="one-to-one")),
    ('group_title', FunctionTransformer(group_title, kw_args={'col':'Title'}, validate=False, feature_names_out='one-to-one'))
])

# %%
fare_pipeline = Pipeline([
    ('fare_per_person', FunctionTransformer(col_per_counts_col, kw_args={'col':'Fare', 'counts_col':'Ticket'}, validate=False, feature_names_out='one-to-one')),
    ('fare_cut', FunctionTransformer(pd.cut, kw_args={'bins':fare_bins, 'labels':'fare_labels'}, validate=False, feature_names_out='one-to-one'))
])

# %%
from sklearn.compose import ColumnTransformer

features_ct = ColumnTransformer(
    transformers=[
        ('title_pipeline', title_pipeline, ['Name']),
        ('make_deck', FunctionTransformer(make_col_off_first_letter, kw_args={'old_col':'Cabin', 'new_col':'Deck'}, validate=False, feature_names_out='one-to-one'), ['Cabin']),
        ('shared_cabin', FunctionTransformer(make_col_off_rep_values, kw_args={'old_col':'Cabin'}, validate=False, feature_names_out='one-to-one'), ['Cabin']),
        ('shared_ticket', FunctionTransformer(make_col_off_rep_values, kw_args={'old_col':'Ticket'}, validate=False, feature_names_out='one-to-one'), ['Ticket']),
        ('fare_pipeline', fare_pipeline, ['Fare', 'Ticket']),
        ('bool_sib', FunctionTransformer(zero_or_greater, kw_args={'col':'SibSp'}, validate=False, feature_names_out='one-to-one'), ['SibSp']),
        ('bool_par', FunctionTransformer(zero_or_greater, kw_args={'col':'Parch'}, validate=False, feature_names_out='one-to-one'), ['Parch'])
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
).set_output(transform="pandas")

# %%
X_train1 = train_set.drop(columns='Survived')

# %%
X_train2 = features_ct.fit_transform(X_train1)
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 X_train2 = features_ct.fit_transform(X_train1)
#
# File ~\titanic\my_env\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\titanic\my_env\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
# ...

# %%
X_train = train_set.drop(columns='Survived')
X_train.head(3)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
